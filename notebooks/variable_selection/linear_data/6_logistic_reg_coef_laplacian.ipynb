# %%
# %cd "~/moses-incons-pen-xp"
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/xabush/moses-incons-pen-xp

# %%
import numpy as np
import pandas as pd
import scipy
import math
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score
import math
from sklearn.model_selection import train_test_split
from datetime import datetime
from notebooks.variable_selection.util import *

# %%
X, beta, y_log = generate_log_data(200, 10, tf_on=4, val_tf=[5, 5, 5, 5], n=200)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_log, test_size=0.5, stratify=y_log)

# %%
assoc_mat = get_assoc_mat(200, 10)

# %%
prec_mat = get_emp_covariance(X_train, assoc_mat)
L_mat_norm = get_laplacian_mat(X_train, X_train, prec_mat, 0.1, True)
L_mat = get_laplacian_mat(X_train, X_train, prec_mat, 0.1, False)

# %%
from notebooks.variable_selection.log_util import log_msg

def beta_noise_pen(gammas, assoc_mat, n_sim=10, n_var=50):

    variance_r = np.logspace(0, 2, n_var)
    variance_r = np.concatenate([np.array([0]), variance_r])
    # beta_vals = np.zeros((len(gammas), n_sim + 1, beta.shape[0]))
    pen_vals_norm = np.zeros((n_sim, len(gammas),  n_var + 1))
    pen_vals_unorm = np.zeros((n_sim, len(gammas), n_var  + 1))

    for i in range(n_sim):
        log_msg(f"Sim {i + 1}...")
        X, beta, _ = generate_log_data(200, 10, tf_on=4, val_tf=[5, 5, 5, 5], n=100)
        prec_mat = get_emp_covariance(X, assoc_mat)

        for j, g in enumerate(gammas):
            L_mat_norm = get_laplacian_mat(X, X, prec_mat, g, True)
            L_mat = get_laplacian_mat(X, X, prec_mat, g, False)
            f = X @ beta
            pen_norm = f.T @ L_mat_norm @ f
            pen_unorm = f.T @ L_mat @ f
            pen_vals_norm[i, j, 0] = pen_norm
            pen_vals_unorm[i, j, 0] = pen_unorm

            for k in range(1, n_var + 1):
                b_noise = np.random.normal(loc=0.0, scale=np.sqrt(variance_r[k]), size=beta.shape[0])
                beta_new = beta + b_noise
                # beta_vals[i, j] = beta_new
                f = X @ beta_new
                pen_norm = f.T @ L_mat_norm @ f
                pen_unorm = f.T @ L_mat @ f

                pen_vals_norm[i, j, k] = pen_norm
                pen_vals_unorm[i, j, k] = pen_unorm

    pen_vals_norm_mean = np.mean(pen_vals_norm, axis=0)
    pen_vals_unorm_mean = np.mean(pen_vals_unorm, axis=0)

    log_msg("Done")
    return variance_r,pen_vals_norm_mean, pen_vals_unorm_mean

def f_noise_pen(gammas, assoc_mat, n_sim=10, n_var=50):

    variance_r = np.logspace(0, 2, n_var)
    variance_r = np.concatenate([np.array([0]), variance_r])
    # beta_vals = np.zeros((len(gammas), n_sim + 1, beta.shape[0]))
    pen_vals_norm = np.zeros((n_sim, len(gammas), n_var + 1))
    pen_vals_unorm = np.zeros((n_sim, len(gammas),n_var  + 1))

    for i in range(n_sim):
        log_msg(f"Sim {i + 1}...")
        X, beta, _ = generate_log_data(200, 10, tf_on=4, val_tf=[5, 5, 5, 5], n=100)
        prec_mat = get_emp_covariance(X, assoc_mat)

        f = X @ beta

        for j, g in enumerate(gammas):
            L_mat_norm = get_laplacian_mat(X, X, prec_mat, g, True)
            L_mat = get_laplacian_mat(X, X, prec_mat, g, False)
            pen_norm = f.T @ L_mat_norm @ f
            pen_unorm = f.T @ L_mat @ f
            pen_vals_norm[i, j, 0] = pen_norm
            pen_vals_unorm[i, j, 0] = pen_unorm

            for k in range(1, n_var + 1):
                f_noise = np.random.normal(loc=np.zeros(f.shape[0]), scale=np.sqrt(variance_r[k]), size=f.shape[0])
                f_new = f + f_noise
                pen_norm = f_new.T @ L_mat_norm @ f_new
                pen_unorm = f_new.T @ L_mat @ f_new

                pen_vals_norm[i, j, k] = pen_norm
                pen_vals_unorm[i, j, k] = pen_unorm

    log_msg("Done.")
    pen_vals_norm_mean = np.mean(pen_vals_norm, axis=0)
    pen_vals_unorm_mean = np.mean(pen_vals_unorm, axis=0)

    return variance_r, pen_vals_norm_mean, pen_vals_unorm_mean

# %%
gammas = np.logspace(-1, 3, 6)

# %%
variance_r, pen_vals_norm, pen_vals_unorm = beta_noise_pen(gammas, assoc_mat)
# Out:
# Sim 1...
# Sim 2...
# Sim 3...
# Sim 4...
# Sim 5...
# Sim 6...
# Sim 7...
# Sim 8...
# Sim 9...
# Sim 10...
# Done

# %%
pen_vals_unorm
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.64713851e-06, 1.12843178e-05, 1.21012964e-05, 1.16281968e-05,
#         1.18171830e-05, 1.08815304e-05, 1.41619562e-05, 1.58732610e-05,
#         1.54496508e-05, 1.72526463e-05, 1.86871160e-05, 2.62336949e-05,
#         2.38300858e-05, 2.37375386e-05, 2.50743261e-05, 2.73528638e-05,
#         2.75990859e-05, 3.82301118e-05, 3.18099594e-05, 3.90813616e-05,
#         4.64144273e-05, 4.91096923e-05, 4.81872584e-05, 6.08414303e-05,
#         6.43839154e-05, 6.68266939e-05, 7.57576157e-05, 8.45174912e-05,
#         8.62905832e-05, 1.07392353e-04, 1.18225030e-04, 1.36576244e-04,
#         1.24661057e-04, 1.22422087e-04, 1.35460320e-04, 1.57096251e-04,
#         1.77790253e-04, 1.95102542e-04, 1.82591216e-04, 2.64141825e-04,
#         2.93398924e-04, 2.65706544e-04, 3.58466924e-04, 4.34064429e-04,
#         3.16862804e-04, 3.83087329e-04, 4.53143274e-04, 4.33728008e-04,
#         6.09851329e-04, 6.25620483e-04, 5.55358587e-04],
#        [4.57907315e+06, 1.31967159e+07, 1.23399647e+07, 1.22074733e+07,
#         1.50191603e+07, 1.59118595e+07, 1.51374490e+07, 1.89249601e+07,
#         1.97348294e+07, 2.27799176e+07, 2.04705489e+07, 2.48471761e+07,
#         2.63015109e+07, 3.09659397e+07, 2.98322671e+07, 3.29881291e+07,
#         3.69430692e+07, 3.89539717e+07, 4.30090556e+07, 4.75684200e+07,
#         5.40093167e+07, 5.11410701e+07, 5.77893880e+07, 6.36762145e+07,
#         6.77199221e+07, 7.96033541e+07, 7.97267620e+07, 9.02006089e+07,
#         9.51539836e+07, 1.13416845e+08, 1.17993824e+08, 1.35873918e+08,
#         1.38781902e+08, 1.62530594e+08, 1.71288721e+08, 1.79113644e+08,
#         2.21831299e+08, 2.26023746e+08, 2.59899357e+08, 2.83621654e+08,
#         3.12041367e+08, 3.29047321e+08, 3.60279675e+08, 4.03770671e+08,
#         4.32751151e+08, 4.87253795e+08, 5.05202821e+08, 5.55772287e+08,
#         6.01267521e+08, 6.87939589e+08, 7.86155056e+08],
#        [9.96742971e+06, 2.62379496e+07, 2.87954982e+07, 2.91916879e+07,
#         3.38923116e+07, 3.60830807e+07, 3.46627289e+07, 3.78627021e+07,
#         4.00633839e+07, 4.39133857e+07, 4.90772058e+07, 4.71897089e+07,
#         5.52679433e+07, 6.11120668e+07, 6.13236313e+07, 7.49640053e+07,
#         8.51957605e+07, 9.29506832e+07, 9.83650878e+07, 1.02765896e+08,
#         1.22299820e+08, 1.20217439e+08, 1.26138014e+08, 1.42403702e+08,
#         1.54554158e+08, 1.69541662e+08, 1.87459027e+08, 2.14129793e+08,
#         2.12022890e+08, 2.28341047e+08, 2.36019659e+08, 3.04651023e+08,
#         2.92120020e+08, 3.53702818e+08, 3.93130828e+08, 3.85393930e+08,
#         4.54072125e+08, 4.20860258e+08, 5.57857021e+08, 6.25158877e+08,
#         6.79804904e+08, 7.37172681e+08, 8.10966427e+08, 8.75104625e+08,
#         9.95310677e+08, 9.34715566e+08, 1.22322924e+09, 1.17203983e+09,
#         1.35424270e+09, 1.63679132e+09, 1.60753170e+09],
#        [1.01646840e+07, 2.74957998e+07, 2.70559480e+07, 2.98552491e+07,
#         3.13624088e+07, 3.41943705e+07, 3.74699530e+07, 3.49822280e+07,
#         3.98829461e+07, 4.96967116e+07, 4.97842794e+07, 5.47924564e+07,
#         5.85576906e+07, 6.33756224e+07, 7.05115822e+07, 6.77352020e+07,
#         7.44329390e+07, 9.06126539e+07, 8.73775193e+07, 1.02364792e+08,
#         1.06300140e+08, 1.21218495e+08, 1.36521391e+08, 1.43192387e+08,
#         1.61724577e+08, 1.63753095e+08, 1.77284748e+08, 1.91767534e+08,
#         2.19293865e+08, 2.38113808e+08, 2.41217283e+08, 2.94209974e+08,
#         3.21372683e+08, 3.46167630e+08, 3.96301210e+08, 4.31111917e+08,
#         4.61043215e+08, 5.02957230e+08, 5.78909290e+08, 5.88921941e+08,
#         6.31423039e+08, 7.69079845e+08, 8.02378739e+08, 9.34203373e+08,
#         9.87874435e+08, 1.07538916e+09, 1.14534966e+09, 1.30956561e+09,
#         1.42453254e+09, 1.41811492e+09, 1.60535302e+09],
#        [1.01696891e+07, 2.68841497e+07, 2.81674009e+07, 3.10538366e+07,
#         3.00459762e+07, 3.25098680e+07, 4.09582788e+07, 3.90182350e+07,
#         4.39717968e+07, 5.17589576e+07, 4.95266944e+07, 5.29251309e+07,
#         5.46377297e+07, 6.16069919e+07, 7.02404751e+07, 6.93975335e+07,
#         8.05022287e+07, 8.47901363e+07, 9.18831076e+07, 9.56621604e+07,
#         1.14127647e+08, 1.17752825e+08, 1.40110097e+08, 1.44476460e+08,
#         1.54564909e+08, 1.70187663e+08, 1.72754315e+08, 2.12867748e+08,
#         2.24229344e+08, 2.35877624e+08, 2.68492635e+08, 2.93266699e+08,
#         3.18776617e+08, 3.27520913e+08, 3.72717895e+08, 4.78010131e+08,
#         4.96769636e+08, 4.89133333e+08, 5.93608466e+08, 5.38871341e+08,
#         6.85631864e+08, 6.77653275e+08, 7.76637765e+08, 8.54579721e+08,
#         1.02854724e+09, 1.08300223e+09, 1.13277303e+09, 1.28340169e+09,
#         1.37337371e+09, 1.40786779e+09, 1.65081012e+09]])

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(variance_r, pen_vals_unorm[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$ (Normalized Laplacian)", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(variance_r, pen_vals_norm[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
variance_r_f, pen_vals_norm_f, pen_vals_unorm_f = f_noise_pen(gammas, assoc_mat)
# Out:
# Sim 1...
# Sim 2...
# Sim 3...
# Sim 4...
# Sim 5...
# Sim 6...
# Sim 7...
# Sim 8...
# Sim 9...
# Sim 10...
# Done.

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $\mathbf{f} = X\beta$ ", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(variance_r_f, pen_vals_unorm_f[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $\mathbf{f} = X\beta$  (Normalized Laplacian)", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(variance_r_f, pen_vals_norm_f[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %% [markdown]
# Penalty vs noise with updated penalty. pen = $f^{T}Lf$, where $f = \frac{1}{1 + e^{-X\beta}}$

# %%
def beta_noise_pen_v2(gammas, assoc_mat, var_range, n_sim=10):

    n_var = len(var_range)
    variance_r = np.concatenate([np.array([0]), var_range])
    # beta_vals = np.zeros((len(gammas), n_sim + 1, beta.shape[0]))
    pen_vals_norm = np.zeros((n_sim, len(gammas),  n_var + 1))
    pen_vals_unorm = np.zeros((n_sim, len(gammas), n_var  + 1))

    for i in range(n_sim):
        log_msg(f"Sim {i + 1}...")
        X, beta, _ = generate_log_data(200, 10, tf_on=4, val_tf=[5, 5, 5, 5], n=100)
        prec_mat = get_emp_covariance(X, assoc_mat)

        for j, g in enumerate(gammas):
            L_mat_norm = get_laplacian_mat(X, X, prec_mat, g, True)
            L_mat = get_laplacian_mat(X, X, prec_mat, g, False)
            f = sigmoid(X @ beta)
            pen_norm = f.T @ L_mat_norm @ f
            pen_unorm = f.T @ L_mat @ f
            pen_vals_norm[i, j, 0] = pen_norm
            pen_vals_unorm[i, j, 0] = pen_unorm

            for k in range(1, n_var + 1):
                b_noise = np.random.normal(loc=0.0, scale=np.sqrt(variance_r[k]), size=beta.shape[0])
                beta_new = beta + b_noise
                # beta_vals[i, j] = beta_new
                f = sigmoid(X @ beta_new)
                pen_norm = f.T @ L_mat_norm @ f
                pen_unorm = f.T @ L_mat @ f

                pen_vals_norm[i, j, k] = pen_norm
                pen_vals_unorm[i, j, k] = pen_unorm

    pen_vals_norm_mean = np.mean(pen_vals_norm, axis=0)
    pen_vals_unorm_mean = np.mean(pen_vals_unorm, axis=0)

    log_msg("Done")
    return variance_r,pen_vals_norm_mean, pen_vals_unorm_mean

def f_noise_pen_v2(gammas, assoc_mat, var_range, n_sim=10):

    n_var = len(var_range)
    variance_r = np.concatenate([np.array([0]), var_range])
    # beta_vals = np.zeros((len(gammas), n_sim + 1, beta.shape[0]))
    pen_vals_norm = np.zeros((n_sim, len(gammas), n_var + 1))
    pen_vals_unorm = np.zeros((n_sim, len(gammas),n_var  + 1))

    for i in range(n_sim):
        log_msg(f"Sim {i + 1}...")
        X, beta, _ = generate_log_data(200, 10, tf_on=4, val_tf=[5, 5, 5, 5], n=100)
        prec_mat = get_emp_covariance(X, assoc_mat)

        f = sigmoid(X @ beta)

        for j, g in enumerate(gammas):
            L_mat_norm = get_laplacian_mat(X, X, prec_mat, g, True)
            L_mat = get_laplacian_mat(X, X, prec_mat, g, False)
            pen_norm = f.T @ L_mat_norm @ f
            pen_unorm = f.T @ L_mat @ f
            pen_vals_norm[i, j, 0] = pen_norm
            pen_vals_unorm[i, j, 0] = pen_unorm

            for k in range(1, n_var + 1):
                f_noise = np.random.normal(loc=np.zeros(f.shape[0]), scale=np.sqrt(variance_r[k]), size=f.shape[0])
                f_new = f + f_noise
                pen_norm = f_new.T @ L_mat_norm @ f_new
                pen_unorm = f_new.T @ L_mat @ f_new

                pen_vals_norm[i, j, k] = pen_norm
                pen_vals_unorm[i, j, k] = pen_unorm

    log_msg("Done.")
    pen_vals_norm_mean = np.mean(pen_vals_norm, axis=0)
    pen_vals_unorm_mean = np.mean(pen_vals_unorm, axis=0)

    return variance_r, pen_vals_norm_mean, pen_vals_unorm_mean

# %% [markdown]
# $\sigma^{2}$ range from 1 to 100

# %%
var_r_3, pen_norm_3, pen_unorm_3 = beta_noise_pen_v2(gammas, assoc_mat, np.logspace(0, 2, 50))
# Out:
# Sim 1...
# /home/xabush/moses-incons-pen-xp/notebooks/variable_selection/util.py:39: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-z))
# Sim 2...
# Sim 3...
# Sim 4...
# Sim 5...
# Sim 6...
# Sim 7...
# Sim 8...
# Sim 9...
# Sim 10...
# Done

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_3, pen_unorm_3[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$ (Normalized Laplacian)", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_3, pen_norm_3[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
var_r_4, pen_norm_4, pen_unorm_4 = f_noise_pen_v2(gammas, assoc_mat, np.logspace(0, 2, 50))
# Out:
# Sim 1...
# Sim 2...
# Sim 3...
# Sim 4...
# Sim 5...
# Sim 6...
# Sim 7...
# Sim 8...
# Sim 9...
# Sim 10...
# Done.

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $f = \frac{1}{1 + e^{-X\beta}}$ ", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_4, pen_unorm_4[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $f = \frac{1}{1 + e^{-X\beta}}$  (Normalized Laplacian) ", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_4, pen_norm_4[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %% [markdown]
# $\sigma^{2}$ range from 0.01 to 1

# %%
var_r_5, pen_norm_5, pen_unorm_5 = beta_noise_pen_v2(gammas, assoc_mat, np.linspace(0.01, 1, 20))
# Out:
# Sim 1...
# Sim 2...
# Sim 3...
# Sim 4...
# Sim 5...
# Sim 6...
# Sim 7...
# Sim 8...
# Sim 9...
# Sim 10...
# Done

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_5, pen_unorm_5[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        # ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$ (Normalized Laplacian)", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_5, pen_norm_5[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        # ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
var_r_6, pen_norm_6, pen_unorm_6 = f_noise_pen_v2(gammas, assoc_mat, np.linspace(0.01, 1, 20))
# Out:
# Sim 1...
# Sim 2...
# Sim 3...
# Sim 4...
# Sim 5...
# Sim 6...
# Sim 7...
# Sim 8...
# Sim 9...
# Sim 10...
# Done.

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $f = \frac{1}{1 + e^{-X\beta}}$ ", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_6, pen_unorm_6[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        # ax[i, j].set_xscale("log")/
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $f = \frac{1}{1 + e^{-X\beta}}$ (Normalized Laplacian)", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_6, pen_norm_6[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        # ax[i, j].set_xscale("log")/
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
var_r_7, pen_norm_7, pen_unorm_7 = beta_noise_pen_v2(gammas, assoc_mat, np.logspace(0, 2, 50), n_sim=100)
# Out:
# Sim 1...

# %%
var_r_8, pen_norm_8, pen_unorm_8 = f_noise_pen_v2(gammas, assoc_mat, np.logspace(0, 2, 50), n_sim=100)

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_7, pen_unorm_7[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$ Normalized Laplacian", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_7, pen_norm_7[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $f = \frac{1}{1 + e^{-X\beta}}$", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_8, pen_unorm_8[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3

# %%
gammas
# Out:
# array([1.00000000e-01, 6.30957344e-01, 3.98107171e+00, 2.51188643e+01,
#        1.58489319e+02, 1.00000000e+03])

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs noise on $f = \frac{1}{1 + e^{-X\beta}}$ (Normalized Laplacian)", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_8, pen_norm_8[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0]
    k += 3

# %%
var_r_9, pen_norm_9, pen_unorm_9 = beta_noise_pen_v2(gammas, assoc_mat, np.linspace(0.01, 1, 20), n_sim=1)
# Out:
# Sim 1...
# Done

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

fig.suptitle(r"Penalty vs added noise on $\mathbf{\beta}$", fontsize=16)

k = 0

for i in range(2):
    for j in range(3):
        idx = j + k
        ax[i, j].plot(var_r_9, pen_unorm_9[idx])
        ax[i, j].set_xlabel(r"$\sigma^{2}$", fontsize=14)
        ax[i, j].set_ylabel(r"$f^{T}Lf$", fontsize=14)
        ax[i, j].set_xscale("log")
        ax[i, j].set_title(f"$\gamma$ = {gammas[idx]}")
        # ax[0].legend()
    k += 3
